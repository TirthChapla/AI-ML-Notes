# %% [markdown]
# **Pandas**

# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('/content/subs.csv')
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Subscribers gained'].plot(kind='hist', bins=20, title='Subscribers gained')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
type(pd.read_csv('/content/subs.csv'))  # DataFrame

# when u read the .csv file using the .read_csv() it always read in DATA_FRAME
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # if we want ot read in the .csv file in the SERIES then we Do:

# %%
# pd.read_csv('/content/subs.csv', squeeze=True)
# this syntax is not working now

# %%
subs = pd.read_csv('/content/subs.csv', header=None).squeeze('columns')

# %%
subs
# Out:
# 0      Subscribers gained
# 1                      48
# 2                      57
# 3                      40
# 4                      43
#               ...
# 361                   231
# 362                   226
# 363                   155
# 364                   144
# 365                   172
# Name: 0, Length: 366, dtype: object

# %% [markdown]
# # Virat kohli IPL

# %%
df = pd.read_csv('/content/kohli_ipl.csv')

vk = df.set_index('match_no')['runs']

# %%
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %% [markdown]
# ##  Bollywood data set

# %%
ds = pd.read_csv('/content/bollywood.csv')
movies = ds.set_index('movie')['lead']

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.head()
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar

# %%
vk.head(10)
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# 6            9
# 7           34
# 8            0
# 9           21
# 10           3

# %%
vk.tail()
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
movies.sample()
# Out:
#                               lead
# movie
# Ek Main Aur Ekk Tu  Kareena Kapoor

# %%
movies.sample(5)
# Out:
#                                          lead
# movie
# Bodyguard (2011 Hindi film)       Salman Khan
# Batla House                      John Abraham
# Aur Pappu Paas Ho Gaya       Krishna Abhishek
# Risknamaa                      Garima Agarwal
# Lakshmi (2014 film)             Monali Thakur

# %%
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Naveen Bawa          1
# Naushaad Abbas       1
# Nauheed Cyrusi       1
# Natalia Janoszek     1
# Nishikant Kamat      1
# Name: count, Length: 566, dtype: int64

# %%
vk.value_counts()
# Out:
# runs
# 0       9
# 1       8
# 12      8
# 9       7
# 8       6
#        ..
# 92      1
# 99      1
# 108     1
# 109     1
# 113     1
# Name: count, Length: 78, dtype: int64

# %%
vk.sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(113)

# %%
vk.count()
# Out:
# np.int64(215)

# %%
vk.sum()
# Out:
# np.int64(6634)

# %%
vk.product()
# Out:
# np.int64(0)

# %%
vk.mean()
# Out:
# np.float64(30.855813953488372)

# %%
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
movies['Uri: The Surgical Strike']
# Out:
# 'Vicky Kaushal'

# %%
vk[3:15
   ]
# Out:
# match_no
# 4     12
# 5      1
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# Name: runs, dtype: int64
