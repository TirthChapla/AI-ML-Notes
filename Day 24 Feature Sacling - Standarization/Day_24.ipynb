# %% [markdown]
# # **Feature Sacling**

# %% [markdown]
# - It is a technique to standardiaze the indepedent features present in the data in a fixed range .
#
# - Ex: col : iq | salary | placement
# -           10   10Lakh     1
#             20   4 LAkh     0
#
# - the difference betwn the iq and salary is to much
#
# - we make both the column is range
#
# - it is called ***Feature Sacling***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Types of Feature Scalling

# %% [markdown]
# ## 1. Standardization (Z-Score Normalization)
# ## 2. Normalization

# %% [markdown]
# # ----------------Standardization :

# %% [markdown]
# z = (x - mean) / standard_deviation

# %% [markdown]
# * So it transforms your data to have:
#
#   * Mean = 0
#
#   * Standard deviation = 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ***Working on Example***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/sample_data/Social_Network_Ads.csv')

# %%
df.head(5)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %% [markdown]
# * we are removing the column user id , gender , age

# %%
df = df.iloc[: , 2 :]

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 151   41            45000          0
# 282   37            70000          1
# 394   39            59000          0
# 83    35            88000          0
# 177   25            22000          0

# %% [markdown]
# # Train Data set & Test Data Set
# ## Split

# %%
from sklearn.model_selection import train_test_split

xTrain , xTest , yTrain , yTest = train_test_split(df.drop('Purchased' , axis=1),df['Purchased'] , test_size = 0.3 , random_state = 0)

# %%
yTrain
# Out:
# 92     0
# 223    1
# 234    0
# 232    1
# 377    0
#       ..
# 323    1
# 192    0
# 117    0
# 47     0
# 172    0
# Name: Purchased, Length: 280, dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)
